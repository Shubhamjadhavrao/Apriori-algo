# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Stationery.csv")

# %%
df.head()
# Out:
#    ID    Name     Item1      Item2      Item3  Item4  Bill
# 0   1  Tushar    Pencil     Eraser   Sharpner    NaN    20
# 1   2  Ramesh       Pen      Pages      Files    Gum    65
# 2   3  Pankaj    Eraser    Perfume  Chocolate    NaN    40
# 3   4  Kartik     Pages      Files    Stapler  Scale   110
# 4   5  Ganesh  Biscuits  Chocolate        NaN    NaN    15

# %%
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Item1     0
# Item2     2
# Item3     6
# Item4    16
# Bill      0
# dtype: int64

# %%
df1=df[['Item1','Item2','Item3','Item4']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      23 non-null     int64
#  1   Name    23 non-null     object
#  2   Item1   23 non-null     object
#  3   Item2   21 non-null     object
#  4   Item3   17 non-null     object
#  5   Item4   7 non-null      object
#  6   Bill    23 non-null     int64
# dtypes: int64(2), object(5)
# memory usage: 1.4+ KB

# %%
df1.head()
# Out:
#       Item1      Item2      Item3  Item4
# 0    Pencil     Eraser   Sharpner    NaN
# 1       Pen      Pages      Files    Gum
# 2    Eraser    Perfume  Chocolate    NaN
# 3     Pages      Files    Stapler  Scale
# 4  Biscuits  Chocolate        NaN    NaN

# %%
records=[]
for i in range(0, 23):
    records.append([str(df1.values[i,j]) for j in range(0, 4)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5973 sha256=024db538e5c904e6c9f9aa18225bda45143afe9de948e6af348a5b1c7babac86
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print("There are {} Relation derived.".format(len(association_results)))
# Out:
# There are 58 Relation derived.

# %%
for i in range(0, len(association_results)):
  print(association_results[i][0])
# Out:
# frozenset({'Sharpner', 'Eraser'})
# frozenset({'Stapler', 'Files'})
# frozenset({'Scale', 'Gum'})
# frozenset({'Sheets', 'Gum'})
# frozenset({'Pages', 'Stapler'})
# frozenset({'Sharpner', 'Pencil'})
# frozenset({'Scale', 'Stapler'})
# frozenset({'Biscuits', 'Pencil', 'Chocolate'})
# frozenset({'Biscuits', 'Scale', 'Chocolate'})
# frozenset({'Biscuits', 'nan', 'Chocolate'})
# frozenset({'Files', 'Compass', 'Chocolate'})
# frozenset({'Eraser', 'Perfume', 'Chocolate'})
# frozenset({'Pages', 'Files', 'Compass'})
# frozenset({'Files', 'Pen', 'Compass'})
# frozenset({'Scale', 'Gum', 'Compass'})
# frozenset({'Sheets', 'Gum', 'Compass'})
# frozenset({'Scale', 'Sheets', 'Compass'})
# frozenset({'Pen', 'Eraser', 'Pencil'})
# frozenset({'Sharpner', 'Pen', 'Eraser'})
# frozenset({'Sharpner', 'Eraser', 'Pencil'})
# frozenset({'Eraser', 'Perfume', 'nan'})
# frozenset({'Sharpner', 'Eraser', 'nan'})
# frozenset({'Pages', 'Gum', 'Files'})
# frozenset({'Pen', 'Gum', 'Files'})
# frozenset({'Scale', 'Gum', 'Files'})
# frozenset({'nan', 'Gum', 'Files'})
# frozenset({'Pages', 'Pen', 'Files'})
# frozenset({'Pages', 'Pencil', 'Files'})
# frozenset({'Scale', 'Pages', 'Files'})
# frozenset({'Pages', 'Stapler', 'Files'})
# frozenset({'Scale', 'Stapler', 'Files'})
# frozenset({'Pages', 'Pen', 'Gum'})
# frozenset({'Scale', 'Sheets', 'Gum'})
# frozenset({'Scale', 'nan', 'Gum'})
# frozenset({'Notebook', 'Perfume', 'Pages'})
# frozenset({'Notebook', 'Pen', 'nan'})
# frozenset({'Notebook', 'Sheets', 'nan'})
# frozenset({'Pages', 'Perfume', 'nan'})
# frozenset({'Scale', 'Pages', 'Stapler'})
# frozenset({'Scale', 'Pen', 'Pencil'})
# frozenset({'Pen', 'Sharpner', 'Pencil'})
# frozenset({'Sharpner', 'Pencil', 'nan'})
# frozenset({'Biscuits', 'nan', 'Pencil', 'Chocolate'})
# frozenset({'Biscuits', 'Scale', 'nan', 'Chocolate'})
# frozenset({'Pen', 'Files', 'Compass', 'Chocolate'})
# frozenset({'nan', 'Eraser', 'Perfume', 'Chocolate'})
# frozenset({'Notebook', 'nan', 'Pen', 'Chocolate'})
# frozenset({'Pages', 'nan', 'Files', 'Compass'})
# frozenset({'Scale', 'Sheets', 'Gum', 'Compass'})
# frozenset({'Sharpner', 'Pen', 'Eraser', 'Pencil'})
# frozenset({'Sharpner', 'Eraser', 'Pencil', 'nan'})
# frozenset({'Pages', 'Pen', 'Gum', 'Files'})
# frozenset({'Scale', 'nan', 'Gum', 'Files'})
# frozenset({'Pages', 'Pen', 'Pencil', 'Files'})
# frozenset({'Scale', 'Pages', 'Stapler', 'Files'})
# frozenset({'Notebook', 'nan', 'Perfume', 'Pages'})
# frozenset({'Notebook', 'Pen', 'Pencil', 'nan'})
# frozenset({'Scale', 'Pen', 'Pencil', 'nan'})

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Sharpner -> Eraser
# Support: 0.13043478260869565
# Confidence: 0.75
# Lift: 5.75
# =====================================
# Rule: Stapler -> Files
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Scale -> Gum
# Support: 0.08695652173913043
# Confidence: 0.6666666666666666
# Lift: 3.0666666666666664
# =====================================
# Rule: Sheets -> Gum
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Pages -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Sharpner -> Pencil
# Support: 0.13043478260869565
# Confidence: 0.42857142857142855
# Lift: 3.2857142857142856
# =====================================
# Rule: Scale -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Biscuits -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Biscuits -> Scale
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Biscuits -> nan
# Support: 0.21739130434782608
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Files -> Compass
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Eraser -> Perfume
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pages -> Files
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Files -> Pen
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Scale -> Gum
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Sheets -> Gum
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Scale -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pen -> Eraser
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: Sharpner -> Pen
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Sharpner -> Eraser
# Support: 0.13043478260869565
# Confidence: 0.75
# Lift: 5.75
# =====================================
# Rule: Eraser -> Perfume
# Support: 0.043478260869565216
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Sharpner -> Eraser
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pages -> Gum
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Pen -> Gum
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Scale -> Gum
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: nan -> Gum
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Pages -> Pen
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: Pages -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Scale -> Pages
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Pages -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Scale -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pages -> Pen
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Scale -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Scale -> nan
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Notebook -> Perfume
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Notebook -> Pen
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 3.8333333333333335
# =====================================
# Rule: Notebook -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pages -> Perfume
# Support: 0.043478260869565216
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Scale -> Pages
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Scale -> Pen
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Pen -> Sharpner
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: Sharpner -> Pencil
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Biscuits -> nan
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Biscuits -> Scale
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pen -> Files
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: nan -> Eraser
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Notebook -> nan
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pages -> nan
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Scale -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Sharpner -> Pen
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Sharpner -> Eraser
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pages -> Pen
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Scale -> nan
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Pages -> Pen
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Scale -> Pages
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Notebook -> nan
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Notebook -> Pen
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 7.666666666666667
# =====================================
# Rule: Scale -> Pen
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 5.75
# =====================================
